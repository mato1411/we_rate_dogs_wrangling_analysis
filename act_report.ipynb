# %%
# %%html
# <style>
# table {align:left;display:block}
# </style>
# Out:
# <style>
# table {align:left;display:block}
# </style>

# %% [markdown]
# # We Rate Dogs Report
#
# This report describes gained insights about the top dog breeds rated by [WeRateDogs](https://twitter.com/dog_rates9).
# The report is based on the analysis of data a WeRateDogs Twitter archive and the information about the predicted breed of dog present in each tweets imaged according to a neural network. Additionally, the Twitter API was used to determine the number of retweet and favorites (likes) of each tweet.
#
# **The Top 10 dog breeds most times rated are**
#
#  |Rank | Dog Breed |                   Times rated|
# | ---|---|---|
# | 1   |  Golden Retriever       |         124|
# | 2    | Pembroke                |         84|
# | 3   |  Labrador Retriever     |          82|
# | 4   |  Chihuahua               |         64|
# | 5   |  Pug                    |          51|
# | 6   |  Samoyed                  |        36|
# | 7    | Pomeranian               |        35|
# | 8   |  Chow                     |        34|
# | 9   |  Toy Poodle             |          33|
# | 10  |  Malamute                |         27|
#
#
# <br>**Top 10 dog breeds very rarely rated**
#
#  Rank | Dog Breed |                   Times rated
#  ---|---|---
#  1   |  Standard Schnauzer            |         1
#  2   |  Toy Terrier                |            1
#  3  |   Japanese Spaniel             |          1
#  4   |  Silky Terrier                |          1
#  5   |  Cairn                         |         1
#  6   |  Afghan Hound                 |          1
#  7   |  Groenendael                 |           1
#  8   |  Entlebucher                 |           1
#  9   |  Wire Haired Fox Terrier     |           1
#  10   | Australian Terrier          |           1
#
# <br>**Top 3 rated dog breeds**
# <br>The highest rating *14/10* was awarded to *17* dog tweets. The top 3 dog breeds most often awarded with the highest rating are.
#
# | Rank | Dog Breed |                   Times with Highest Rating|
# | ---|---|---|
# | 1   |  Pembroke                     |               3|
# | 2  |   Golden Retriever                     |       2
# | 3   |  French Bulldog                     |         2|
#
# <br>**Worst 3 rated dog breeds**
#
# |Rank  |Dog Breed       |   Rating   |   Times with Lowest Rating|
# | ---|---|---|---|
# |1     |Maltese Dog      |       2         |                    1|
# |2    | Chihuahua         |      3        |                     1|
# |3    | Pug               |      3      |                       1|
#
# <br>**Top 3 dog breeds with highest retweet count**
#
# |Rank | Dog Breed             |Retweet Count     | Favorite Count|
# | ---|---|---|---|
# |1     |Labrador Retriever         |   73824          |    149760|
# |2     |Eskimo Dog                 |   55021           |   110825|
# |3     |Chihuahua                  |   53843           |   115713|
#
# <br>**Worst 3 dog breeds with highest favorite count**
#
# |Rank | Dog Breed             |Favorite Count     | Retweet Count|
# | ---|---|---|---|
# |1   |  Labrador Retriever         |       149760    |      73824|
# |2    | Chihuahua                |         115713        |  53843|
# |3   |  French Bulldog          |          112283      |    31459|
#
# <br>**Top 10 dog breeds with highest rating sum**
#
# | Rank | Dog Breed |                   Rating Sum|
# | ---|---|---|
# |1    | Golden Retriever   |                 1437|
# |2   |  Pembroke                     |        959|
# |3  |   Labrador Retriever          |         911|
# |4     |Chihuahua                |            675|
# |5    | Pug                        |          523|
# |6    | Samoyed                    |          422|
# |7   |  Chow                     |            395|
# |8   |  Pomeranian                |           390|
# |9   |  Toy Poodle              |             367|
# |10   | Malamute                |             295|
#
# <br>**Top 10 dog breeds with highest favorite count sum**
#
# | Rank | Dog Breed |                   Favorite Count Sum|
# | ---|---|---|
# |1   |  Golden Retriever          |       1383552|
# |2   |  Labrador Retriever           |     924991|
# |3   |  Pembroke                   |       869362|
# |4   |  Chihuahua                 |        510246|
# |5    | Samoyed                  |         412649|
# |6   |  French Bulldog                |    403292|
# |7   |  Chow                   |           314061|
# |8    | Pug                     |          253118|
# |9    | Cocker Spaniel               |     245059|
# |10   | Eskimo Dog                   |     228203|
#
# <br>**Top 10 dog breeds with highest retweet count sum**
#
# | Rank | Dog Breed |                   Retweet Count Sum|
# | ---|---|---|
# |1   |  Golden Retriever         |         374605|
# |2     |Labrador Retriever      |          288413|
# |3   |  Pembroke               |           230666|
# |4  |   Chihuahua              |           164855|
# |5  |   Samoyed                |           131260|
# |6   |  French Bulldog       |              98362|
# |7  |   Chow                |               84088|
# |8  |   Eskimo Dog          |               81047|
# |9  |   Cocker Spaniel     |                76625|
# |10  |  Pomeranian        |                 72692|
#
# The following illustrations show the sum of Favorite and Retweet Counts for all Dog Breeds in the Top 10 Intersection of Favorite Count, Retweet Count and Rating sums.
#
# ![](fav_retweet_top_10_report.png)
